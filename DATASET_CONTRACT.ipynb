# %% [markdown]
# **NGUỒN:** https://thuvienphapluat.vn

# %% [markdown]
# #**LẤY NỘI DUNG HỢP ĐỒNG TỪ TRANG WEB**

# %%
import os, re, csv, time, hashlib
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

# -------- Cấu hình ----------
BASE = "https://thuvienphapluat.vn"
LIST_URL = BASE + "/hopdong?page={page}"
NUM_PAGES = 5            # tăng nếu muốn crawl nhiều trang hơn
DELAY_SEC = 1.0
MIN_WORDS = 60           # tối thiểu số từ để giữ file
OUTPUT_DIR = "contracts_html_window"
CSV_MANIFEST = "contracts_html_window_manifest.csv"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "vi-VN,vi;q=0.9,en-US;q=0.8,en;q=0.7",
}

# --------- Tiện ích ----------
def fetch_html(url: str) -> str:
    r = requests.get(url, headers=HEADERS, timeout=30)
    r.raise_for_status()
    r.encoding = "utf-8"
    return r.text

def sha1_of(t: str) -> str:
    return hashlib.sha1(t.encode("utf-8", "ignore")).hexdigest()

def safe_filename(n: str) -> str:
    n = re.sub(r"[\\/*?:\"<>|]+", "_", n).strip()
    return (n or f"hopdong_{int(time.time())}.txt")[:180]

def clean_text_soft(t: str) -> str:
    if not t: return ""
    t = t.replace("\r", "")
    t = re.sub(r"[ \t]{2,}", " ", t)
    # giữ xuống dòng để bảo toàn biểu mẫu
    t = re.sub(r"\n{3,}", "\n\n", t)
    return t.strip()

# ---------- Nhận dạng hợp đồng/biểu mẫu ----------
KEY_PATTERNS = [
    r"\bHỢP\s*ĐỒNG\b", r"\bHOP\s*DONG\b",
    r"\bPHỤ\s*LỤC\b",  r"\bPHU\s*LUC\b",
    r"\bBIÊN\s*BẢN\b", r"\bBIEN\s*BAN\b",
    r"\bTHANH\s*LÝ\b", r"\bTHANH\s*LY\b",
    r"\bNGHIỆM\s*THU\b", r"\bNGHIEM\s*THU\b",
    r"\bCỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM\b",
    r"\bCONG HOA XA HOI CHU NGHIA VIET NAM\b",
    r"\b(PL|PL\d{1,3})[-\s]*[A-Z0-9À-Ỹ]{1,10}\b",
    r"\bMẪU\s+HỢP\s*ĐỒNG\b", r"\bMAU\s+HOP\s*DONG\b",
    r"^\s*Căn\s*cứ\s*:\s*$",   r"^\s*Can\s*cu\s*:\s*$",
    r"^\s*Số\s*:\s*.*$",       r"^\s*So\s*:\s*.*$",
    r"\bHỢP ĐỒNG TƯ VẤN XÂY DỰNG\b", r"\bHOP DONG TU VAN XAY DUNG\b",
]
KEY_RE = re.compile("|".join(KEY_PATTERNS), re.I | re.U)

def looks_like_contract(text: str) -> bool:
    return bool(text and KEY_RE.search(text))

# ---------- Các mốc "bắt đầu nội dung hợp đồng" ----------
START_ANCHORS = [
    r"\bHỢP ĐỒNG TƯ VẤN XÂY DỰNG\b",
    r"\bMẪU\s+HỢP\s*ĐỒNG\b",
    r"\bCỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM\b",
    r"^\s*Căn\s*cứ\s*:\s*$",
    r"^\s*Thông\s*tư\s+\d{1,3}/\d{4}/TT-[A-ZĐ]{2,}\b",
    r"^\s*Số\s*:\s*.*$",
    r"\bBIÊN\s*BẢN\b", r"\bPHỤ\s*LỤC\b",  # dự phòng
]
START_RE = re.compile("|".join(START_ANCHORS), re.I | re.U)

# ---------- Rác menu/banner chắc chắn ----------
JUNK_PATTERNS_STRICT = [
    r"^\s*THƯ VIỆN PHÁP LUẬT\s*$",
    r"^\s*Trang Thông tin điện tử tổng hợp\s*$",
    r"^\s*(Tra cứu|Văn bản và Tra cứu|Chính sách Pháp\s*luật mới|Pháp Luật|Liên hệ|Danh mục)\s*$",
    r"^\s*(Tra cứu Pháp Luật mới|Tra cứu Văn Bản trực tuyến|Tra cứu Dự thảo|Văn bản mới ban hành)\s*$",
    r"^\s*(Tra cứu Tiêu Chuẩn|ICS .*|Tra cứu Công Văn|Thuật ngữ pháp lý|Tra cứu Bản án)\s*$",
    r"^\s*(Luật sư toàn quốc|Website ngành luật|Hỏi đáp pháp luật|PHÁP LUẬT DOANH NGHIỆP)\s*$",
    r"^\s*(Bảng giá đất|Mẫu hợp đồng|Biểu mẫu|Mức phí, lệ phí|Diện tích tách thửa đất ở)\s*$",
    r"^\s*(Rss|Homepage|Giới thiệu|Hướng dẫn sử dụng|Widget|Phần mềm|Đại lý phân phối)\s*$",
    r"^\s*(Bạn hãy nhập e-mail|E-?mail\s*:).*$",
    r"^\s*(Đăng nhập|Đăng ký|Sử dụng tài khoản)\s*$",
    r"^\s*(Law\s*Net|iThong)\s*$",
    r"^\s*(Tải về|Chỉnh sửa và tải về)\s*$",
    r"^\s*Cập nhật:\s*\d{2}/\d{2}/\d{4}\s*$",
    r"^\s*\d+\.\s*$",
    r"^\s*\d+\.\s*[A-Za-zÀ-Ỹà-ỹ0-9].{0,80}$",
    r"^\s*\.\.\.|=>\s*$",
]
JUNK_RE = re.compile("|".join(JUNK_PATTERNS_STRICT), re.I | re.U)

# ---------- Lấy link chi tiết ----------
def extract_detail_links(list_html: str):
    soup = BeautifulSoup(list_html, "html.parser")
    links = []
    for a in soup.select("a[href*='/hopdong/']"):
        href = a.get("href", "")
        if "/hopdong/" in href and not href.rstrip("/").endswith("/hopdong"):
            links.append(urljoin(BASE, href))
    # bỏ link tải file trực tiếp nếu có
    links = [u for u in dict.fromkeys(links) if not re.search(r"\.(docx?|pdf)(\?|$)", u, re.I)]
    return links

# ---------- Cắt theo cửa sổ và lọc rác ----------
CONTENT_SELECTORS = [
    "div#divContent", ".hopdong-detail", ".content-detail", "article", "main", ".content", ".post-content"
]

def crop_and_clean_contract(text: str) -> str:
    if not text: return ""
    text = text.replace("\r", "")
    # không nén quá tay — giữ định dạng form
    text = re.sub(r"[ \t]{2,}", " ", text)

    lines = text.splitlines()
    # tìm chỉ số bắt đầu từ mốc
    start_idx = 0
    for i, l in enumerate(lines):
        if START_RE.search(l) or KEY_RE.search(l):
            start_idx = i
            break
    core = lines[start_idx:]  # cắt phần đầu là menu/breadcrumb

    keep = []
    for l in core:
        ls = l.strip()
        if not ls:
            keep.append(l); continue
        # luôn giữ nếu có từ khoá/mốc
        if START_RE.search(ls) or KEY_RE.search(ls):
            keep.append(l); continue
        # xoá các dòng rác chắc chắn là menu/banner
        if JUNK_RE.search(ls):
            continue
        keep.append(l)

    out = "\n".join(keep)
    out = re.sub(r"\n{3,}", "\n\n", out).strip()
    return out

def extract_html_window(url: str):
    html = fetch_html(url)
    soup = BeautifulSoup(html, "html.parser")

    node = None
    for sel in CONTENT_SELECTORS:
        node = soup.select_one(sel)
        if node: break
    raw = node.get_text("\n", strip=True) if node else soup.get_text("\n", strip=True)

    text = crop_and_clean_contract(raw)

    title_el = soup.find("h1") or soup.find("title")
    title = title_el.get_text(strip=True) if title_el else "Không tiêu đề"
    return title, text

# ---------- Ghi file ----------
def write_txt_clean(path: str, content: str):
    with open(path, "w", encoding="utf-8") as f:
        f.write("### NOIDUNG_SACH ###\n")
        f.write(content)
        f.write("\n### END_NOIDUNG_SACH ###\n")

# ---------- Main ----------
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    seen = set()
    total = 0

    with open(CSV_MANIFEST, "w", encoding="utf-8", newline="") as cf:
        w = csv.DictWriter(cf, fieldnames=["filename","title","url","words","sha1","crawled_at"])
        w.writeheader()

        for p in range(1, NUM_PAGES+1):
            list_url = LIST_URL.format(page=p)
            print(f"\n=== Trang {p}/{NUM_PAGES} ===")
            try:
                list_html = fetch_html(list_url)
            except Exception as e:
                print("Lỗi tải trang:", e); continue

            for link in extract_detail_links(list_html):
                print("→", link)
                try:
                    title, text = extract_html_window(link)
                except Exception as e:
                    print("HTML error:", e); continue

                if not looks_like_contract(text):
                    continue
                if len(text.split()) < MIN_WORDS:
                    continue

                digest = sha1_of(text)
                if digest in seen:
                    continue
                seen.add(digest)

                fname = safe_filename(title)
                path = os.path.join(OUTPUT_DIR, fname)
                write_txt_clean(path, text)

                w.writerow({
                    "filename": fname,
                    "title": title,
                    "url": link,
                    "words": len(text.split()),
                    "sha1": digest,
                    "crawled_at": time.strftime("%Y-%m-%d %H:%M:%S"),
                })

                total += 1
                print(f"{fname} ({len(text.split())} từ)")
                time.sleep(DELAY_SEC)

    print(f"\n=== HOÀN TẤT ===\nTổng: {total}\nLưu: {OUTPUT_DIR}\nManifest: {CSV_MANIFEST}")

if __name__ == "__main__":
    main()
# Out:
# === Trang 1/5 ===
# → https://thuvienphapluat.vn/hopdong/779/HOP-DONG-TU-VAN-XAY-DUNG
# HỢP ĐỒNG TƯ VẤN XÂY DỰNG (14137 từ)
# → https://thuvienphapluat.vn/hopdong/38386/MAU-HOP-DONG-TIEP-CAN-NGUON-GEN-VA-CHIA-SE-LOI-ICH-Khi-thuc-hien-chinh-quyen-02-cap
# MẪU HỢP ĐỒNG TIẾP CẬN NGUỒN GEN VÀ CHIA SẺ LỢI ÍCH (Khi thực hiện chính quyền 02 cấp) (3472 từ)
# → https://thuvienphapluat.vn/hopdong/38383/HOP-DONG-HOP-TAC-TO-HOP-TAC
# HỢP ĐỒNG HỢP TÁC (TỔ HỢP TÁC) (3509 từ)
# → https://thuvienphapluat.vn/hopdong/37364/BIEN-BAN-NGHIEM-THU-THANH-LY-HOP-DONG-THUC-HIEN-NHIEM-VU-SU-NGHIEP-KINH-TE-BO-XAY-DUNG
# BIÊN BẢN NGHIỆM THU THANH LÝ HỢP ĐỒNG THỰC HIỆN NHIỆM VỤ SỰ NGHIỆP KINH TẾ (BỘ XÂY DỰNG) (2012 từ)
# → https://thuvienphapluat.vn/hopdong/37363/HOP-DONG-THUC-HIEN-NHIEM-VU-SU-NGHIEP-KINH-TE-BO-XAY-DUNG
# HỢP ĐỒNG THỰC HIỆN NHIỆM VỤ SỰ NGHIỆP KINH TẾ (BỘ XÂY DỰNG) (2326 từ)
# → https://thuvienphapluat.vn/hopdong/37362/BIEN-BAN-THANH-LY-HOP-DONG-THUC-HIEN-NHIEM-VU-BAO-VE-MOI-TRUONG-BO-XAY-DUNG
# BIÊN BẢN THANH LÝ HỢP ĐỒNG THỰC HIỆN NHIỆM VỤ BẢO VỆ MÔI TRƯỜNG (BỘ XÂY DỰNG) (2518 từ)
# → https://thuvienphapluat.vn/hopdong/37361/HOP-DONG-THUC-HIEN-NHIEM-VU-BAO-VE-MOI-TRUONG-voi-cac-co-quan-chu-tri-thuc-hien-la-don-vi-du-toan-truc-thuoc-Bo-Xay-dung
# HỢP ĐỒNG THỰC HIỆN NHIỆM VỤ BẢO VỆ MÔI TRƯỜNG (với các cơ quan chủ trì thực hiện là đơn vị dự toán trực thuộc Bộ Xây dựng) (3665 từ)
# → https://thuvienphapluat.vn/hopdong/37360/HOP-DONG-THUC-HIEN-NHIEM-VU-BAO-VE-MOI-TRUONG-voi-cac-co-quan-chu-tri-thuc-hien-nhiem-vu-co-kinh-phi-cap-qua-tai-khoan-Van-phong-Bo-Xay-dung
# HỢP ĐỒNG THỰC HIỆN NHIỆM VỤ BẢO VỆ MÔI TRƯỜNG (với các cơ quan chủ trì thực hiện nhiệm vụ có kinh phí cấp qua tài khoản Văn phòng Bộ Xây dựng) (3781 từ)
# → https://thuvienphapluat.vn/hopdong/37359/HOP-DONG-VAY-VA-CHO-VAY-CHUNG-KHOAN
# HỢP ĐỒNG VAY VÀ CHO VAY CHỨNG KHOÁN (3157 từ)
# → https://thuvienphapluat.vn/hopdong/37358/HOP-DONG-MO-TAI-KHOAN-GIAO-DICH-CHUNG-KHOAN-PHAI-SINH
# HỢP ĐỒNG MỞ TÀI KHOẢN GIAO DỊCH CHỨNG KHOÁN PHÁI SINH (2445 từ)
# → https://thuvienphapluat.vn/hopdong/37357/HOP-DONG-UY-THAC-BU-TRU-THANH-TOAN
# HỢP ĐỒNG ỦY THÁC BÙ TRỪ, THANH TOÁN (2526 từ)
# → https://thuvienphapluat.vn/hopdong/36918/HOP-DONG-LAO-DONG
# HỢP ĐỒNG LAO ĐỘNG (3003 từ)
# → https://thuvienphapluat.vn/hopdong/36621/HOP-DONG-THU-VIEC
# HỢP ĐỒNG THỬ VIỆC (2442 từ)
# → https://thuvienphapluat.vn/hopdong/36620/HOP-DONG-THU-VIEC
# → https://thuvienphapluat.vn/hopdong/36308/VAN-BAN-SUA-DOI-BO-SUNG-HOP-DONG-THE-CHAP-TAI-SAN-Tai-san-the-chap-la-nha-o-xa-hoi-nha-o-cho-luc-luong-vu-trang-nhan-dan-hinh-thanh-trong-tuong-lai
# VĂN BẢN SỬA ĐỔI, BỔ SUNG HỢP ĐỒNG THẾ CHẤP TÀI SẢN (Tài sản thế chấp là nhà ở xã hội, nhà ở cho lực lượng vũ trang nhân dân hình thành trong tương lai) (2695 từ)
# MẪU LOẠI HỢP ĐỒNG BOT ĐỐI VỚI DỰ ÁN CẤP NƯỚC SẠCH NÔNG THÔN (Hợp đồng Xây dựng - Kinh Doanh - Chuyển giao đối với dự án cấp nước sạch nông thôn) (20294 từ)
# → https://thuvienphapluat.vn/hopdong/33393/MAU-LOAI-HOP-DONG-BLT-DOI-VOI-DU-AN-THUY-LOI-Hop-dong-Xay-dung-Thue-dich-vu-Chuyen-giao-doi-voi-du-an-thuy-loi
# MẪU LOẠI HỢP ĐỒNG BLT ĐỐI VỚI DỰ ÁN THỦY LỢI (Hợp đồng Xây dựng - Thuê dịch vụ - Chuyển giao đối với dự án thủy lợi) (20520 từ)
# → https://thuvienphapluat.vn/hopdong/379/HOP-DONG-CUNG-CAP-DICH-VU-PHU-TRO-HE-THONG-DIEN
# HỢP ĐỒNG CUNG CẤP DỊCH VỤ PHỤ TRỢ HỆ THỐNG ĐIỆN (11768 từ)
# → https://thuvienphapluat.vn/hopdong/150/BIEN-BAN-THANH-LY-HOP-DONG
# → https://thuvienphapluat.vn/hopdong/156/HOP-DONG-HOP-TAC-KINH-DOANH-mau-1
# → https://thuvienphapluat.vn/hopdong/109/HOP-DONG-MUA-BAN-HANG-HOA
# → https://thuvienphapluat.vn/hopdong/230/HOP-DONG-MUA-BAN-NHA-O-mau-2
# → https://thuvienphapluat.vn/hopdong/130/HOP-DONG-NGUYEN-TAC-BAN-HANG
#
# === Trang 3/5 ===
# → https://thuvienphapluat.vn/hopdong/33364/HOP-DONG-CHUYEN-NHUONG-HOP-DONG-MUA-BAN-HOP-DONG-THUE-MUA-NHA-O-CONG-TRINH-XAY-DUNG
# HỢP ĐỒNG CHUYỂN NHƯỢNG HỢP ĐỒNG MUA BÁN, HỢP ĐỒNG THUÊ MUA NHÀ Ở, CÔNG TRÌNH XÂY DỰNG (4943 từ)
# → https://thuvienphapluat.vn/hopdong/33363/HOP-DONG-CHUYEN-NHUONG-MOT-PHAN-DU-AN-BAT-DONG-SAN
# HỢP ĐỒNG CHUYỂN NHƯỢNG MỘT PHẦN DỰ ÁN BẤT ĐỘNG SẢN (5106 từ)
# → https://thuvienphapluat.vn/hopdong/33362/HOP-DONG-CHUYEN-NHUONG-TOAN-BO-DU-AN-BAT-DONG-SAN
# HỢP ĐỒNG CHUYỂN NHƯỢNG TOÀN BỘ DỰ ÁN BẤT ĐỘNG SẢN (5024 từ)
# → https://thuvienphapluat.vn/hopdong/33361/HOP-DONG-CHO-THUE-HOP-DONG-CHO-THUE-LAI-QUYEN-SU-DUNG-DAT-DA-CO-HA-TANG-KY-THUAT-TRONG-DU-AN-BAT-DONG-SAN
# HỢP ĐỒNG CHO THUÊ, HỢP ĐỒNG CHO THUÊ LẠI QUYỀN SỬ DỤNG ĐẤT ĐÃ CÓ HẠ TẦNG KỸ THUẬT TRONG DỰ ÁN BẤT ĐỘNG SẢN (5063 từ)
# → https://thuvienphapluat.vn/hopdong/33360/HOP-DONG-CHUYEN-NHUONG-QUYEN-SU-DUNG-DAT-DA-CO-HA-TANG-KY-THUAT-TRONG-DU-AN-BAT-DONG-SAN
# → https://thuvienphapluat.vn/hopdong/33351/HOP-DONG-MUA-BAN-HOP-DONG-THUE-MUA-PHAN-DIEN-TICH-SAN-XAY-DUNG-TRONG-CONG-TRINH-XAY-DUNG-Hop-dong-mau-ap-dung-trong-ban-cho-thue-mua-phan-dien-tich-san-xay-dung-trong-cong-trinh-xay-dung-co-cong-nang-phuc-vu-muc-dich-du-lich-luu-tru
# HỢP ĐỒNG MUA BÁN, HỢP ĐỒNG THUÊ MUA PHẦN DIỆN TÍCH SÀN XÂY DỰNG TRONG CÔNG TRÌNH XÂY DỰNG (Hợp đồng mẫu áp dụng trong bán, cho thuê mua phần diện tích sàn xây dựng trong công trình (18131 từ)
# → https://thuvienphapluat.vn/hopdong/33350/HOP-DONG-THUE-NHA-O
# HỢP ĐỒNG THUÊ NHÀ Ở (3843 từ)
# → https://thuvienphapluat.vn/hopdong/33349/HOP-DONG-MUA-BAN-HOP-DONG-THUE-MUA-NHA-O-HOP-DONG-MAU-AP-DUNG-TRONG-MUA-BAN-CHO-THUE-MUA-NHA-O-RIENG-LE
# HỢP ĐỒNG MUA BÁN_HỢP ĐỒNG THUÊ MUA NHÀ Ở (HỢP ĐỒNG MẪU ÁP DỤNG TRONG MUA BÁN, CHO THUÊ MUA NHÀ Ở RIÊNG LẺ) (10258 từ)
# → https://thuvienphapluat.vn/hopdong/33348/HOP-DONG-CHO-THUE-MUA-NHA-O-HOP-DONG-MAU-AP-DUNG-TRONG-THUE-MUA-CAN-HO-CHUNG-CU
# HỢP ĐỒNG CHO THUÊ MUA NHÀ Ở (HỢP ĐỒNG MẪU ÁP DỤNG TRONG THUÊ MUA CĂN HỘ CHUNG CƯ) (13346 từ)
# → https://thuvienphapluat.vn/hopdong/33347/HOP-DONG-MUA-BAN-NHA-O-HOP-DONG-MAU-AP-DUNG-TRONG-MUA-BAN-CAN-HO-CHUNG-CU
# HỢP ĐỒNG MUA BÁN NHÀ Ở (HỢP ĐỒNG MẪU ÁP DỤNG TRONG MUA BÁN CĂN HỘ CHUNG CƯ) (13032 từ)
# → https://thuvienphapluat.vn/hopdong/33301/HOP-DONG-MUA-BAN-NHA-O-CU-THUOC-TAI-SAN-CONG
# HỢP ĐỒNG MUA BÁN NHÀ Ở CŨ THUỘC TÀI SẢN CÔNG (3420 từ)
# → https://thuvienphapluat.vn/hopdong/33299/HOP-DONG-THUE-NHA-O-XA-HOI
# HỢP ĐỒNG THUÊ NHÀ Ở XÃ HỘI (4496 từ)
# → https://thuvienphapluat.vn/hopdong/33297/HOP-DONG-THUE-MUA-NHA-O-XA-HOI
# HỢP ĐỒNG THUÊ MUA NHÀ Ở XÃ HỘI (4413 từ)
# → https://thuvienphapluat.vn/hopdong/33295/HOP-DONG-MUA-BAN-NHA-O-XA-HOI
# HỢP ĐỒNG MUA BÁN NHÀ Ở XÃ HỘI (4402 từ)
# → https://thuvienphapluat.vn/hopdong/33292/HOP-DONG-CHO-THUE-NHA-O-PHUC-VU-TAI-DINH-CU-HOAC-NHA-O-CU-THUOC-TAI-SAN-CONG
# HỢP ĐỒNG CHO THUÊ NHÀ Ở PHỤC VỤ TÁI ĐỊNH CƯ HOẶC NHÀ Ở CŨ THUỘC TÀI SẢN CÔNG (4170 từ)
# → https://thuvienphapluat.vn/hopdong/150/BIEN-BAN-THANH-LY-HOP-DONG
# → https://thuvienphapluat.vn/hopdong/156/HOP-DONG-HOP-TAC-KINH-DOANH-mau-1
# → https://thuvienphapluat.vn/hopdong/109/HOP-DONG-MUA-BAN-HANG-HOA
# → https://thuvienphapluat.vn/hopdong/230/HOP-DONG-MUA-BAN-NHA-O-mau-2
# → https://thuvienphapluat.vn/hopdong/130/HOP-DONG-NGUYEN-TAC-BAN-HANG
#
# === Trang 4/5 ===
# → https://thuvienphapluat.vn/hopdong/33289/HOP-DONG-CHO-THUE-MUA-NHA-O-PHUC-VU-TAI-DINH-CU
# HỢP ĐỒNG CHO THUÊ MUA NHÀ Ở PHỤC VỤ TÁI ĐỊNH CƯ (4393 từ)
# → https://thuvienphapluat.vn/hopdong/33288/HOP-DONG-MUA-BAN-NHA-O-PHUC-VU-TAI-DINH-CU
# HỢP ĐỒNG MUA BÁN NHÀ Ở PHỤC VỤ TÁI ĐỊNH CƯ (3922 từ)
# → https://thuvienphapluat.vn/hopdong/33187/DIEU-CHINH-HOP-DONG-THUE-DAT
# ĐIỀU CHỈNH HỢP ĐỒNG THUÊ ĐẤT (1902 từ)
# → https://thuvienphapluat.vn/hopdong/353/HOP-DONG-THUE-DAT
# HỢP ĐỒNG THUÊ ĐẤT (2603 từ)
# → https://thuvienphapluat.vn/hopdong/33091/HOP-DONG-THUE-RUNG
# HỢP ĐỒNG THUÊ RỪNG (2655 từ)
# → https://thuvienphapluat.vn/hopdong/33090/HOP-DONG-CHO-THUE-MOI-TRUONG-RUNG-DE-KINH-DOANH-DICH-VU-DU-LICH-SINH-THAI-NGHI-DUONG-GIAI-TRI-TRONG-RUNG-DAC-DUNG-PHONG-HO-SAN-XUAT
# HỢP ĐỒNG CHO THUÊ MÔI TRƯỜNG RỪNG ĐỂ KINH DOANH DỊCH VỤ DU LỊCH SINH THÁI, NGHỈ DƯỠNG, GIẢI TRÍ TRONG RỪNG ĐẶC DỤNG_PHÒNG HỘ_SẢN XUẤT (4638 từ)
# → https://thuvienphapluat.vn/hopdong/33089/HOP-DONG-MOI-GIOI-THUONG-MAI
# HỢP ĐỒNG MÔI GIỚI THƯƠNG MẠI (2863 từ)
# → https://thuvienphapluat.vn/hopdong/29436/HOP-DONG-CONG-TAC-VIEN-TRUNG-TAM-TU-VAN-PHAP-LUAT
# HỢP ĐỒNG CỘNG TÁC VIÊN TRUNG TÂM TƯ VẤN PHÁP LUẬT (2205 từ)
# → https://thuvienphapluat.vn/hopdong/29301/HOP-DONG-DUA-NGUOI-LAO-DONG-DI-LAM-VIEC-O-NUOC-NGOAI
# HỢP ĐỒNG ĐƯA NGƯỜI LAO ĐỘNG ĐI LÀM VIỆC Ở NƯỚC NGOÀI (4549 từ)
# → https://thuvienphapluat.vn/hopdong/29257/MAU-HOP-DONG-THUE-MUA-NHA-O-TAI-DINH-CU
# MẪU HỢP ĐỒNG THUÊ MUA NHÀ Ở TÁI ĐỊNH CƯ (4174 từ)
# HỢP ĐỒNG TÍN DỤNG (ĐỐI VỚI NGƯỜI LAO ĐỘNG ĐI LÀM VIỆC Ở NƯỚC NGOÀI THEO HỢP ĐỒNG) (4702 từ)
# → https://thuvienphapluat.vn/hopdong/28306/PHU-LUC-HOP-DONG-VE-QUAN-LY-VA-SU-DUNG-TAI-KHOAN-CHUNG-TAI-NGAN-HANG-CHINH-SACH-XA-HOI
# PHỤ LỤC HỢP ĐỒNG VỀ QUẢN LÝ VÀ SỬ DỤNG TÀI KHOẢN CHUNG (TẠI NGÂN HÀNG CHÍNH SÁCH XÃ HỘI) (2768 từ)
# → https://thuvienphapluat.vn/hopdong/28305/GIAY-DE-NGHI-KIEM-HOP-DONG-MO-TAI-KHOAN-TIEN-GUI-CHUNG-TAI-NGAN-HANG-CHINH-SACH-XA-HOI
# GIẤY ĐỀ NGHỊ KIÊM HỢP ĐỒNG MỞ TÀI KHOẢN TIỀN GỬI CHUNG (TẠI NGÂN HÀNG CHÍNH SÁCH XÃ HỘI) (2518 từ)
# → https://thuvienphapluat.vn/hopdong/150/BIEN-BAN-THANH-LY-HOP-DONG
# → https://thuvienphapluat.vn/hopdong/156/HOP-DONG-HOP-TAC-KINH-DOANH-mau-1
# → https://thuvienphapluat.vn/hopdong/109/HOP-DONG-MUA-BAN-HANG-HOA
# → https://thuvienphapluat.vn/hopdong/230/HOP-DONG-MUA-BAN-NHA-O-mau-2
# → https://thuvienphapluat.vn/hopdong/130/HOP-DONG-NGUYEN-TAC-BAN-HANG
#
# === Trang 5/5 ===
# → https://thuvienphapluat.vn/hopdong/28304/GIAY-DE-NGHI-KIEM-HOP-DONG-MO-TAI-KHOAN-TIEN-GUI-DANH-CHO-CA-NHAN-TAI-NGAN-HANG-CHINH-SACH-XA-HOI
# GIẤY ĐỀ NGHỊ KIÊM HỢP ĐỒNG MỞ TÀI KHOẢN TIỀN GỬI DÀNH CHO CÁ NHÂN (TẠI NGÂN HÀNG CHÍNH SÁCH XÃ HỘI) (2470 từ)
# → https://thuvienphapluat.vn/hopdong/28303/GIAY-DE-NGHI-KIEM-HOP-DONG-MO-TAI-KHOAN-TIEN-GUI-DANH-CHO-TO-CHUC-TAI-NGAN-HANG-CHINH-SACH-XA-HOI
# GIẤY ĐỀ NGHỊ KIÊM HỢP ĐỒNG MỞ TÀI KHOẢN TIỀN GỬI DÀNH CHO TỔ CHỨC (TẠI NGÂN HÀNG CHÍNH SÁCH XÃ HỘI) (2468 từ)
# → https://thuvienphapluat.vn/hopdong/192/HOP-DONG-TANG-CHO-QUYEN-SU-DUNG-DAT-VA-TAI-SAN-GAN-LIEN-VOI-DAT
# HỢP ĐỒNG TẶNG CHO QUYỀN SỬ DỤNG ĐẤT VÀ TÀI SẢN GẮN LIỀN VỚI ĐẤT (3307 từ)
# → https://thuvienphapluat.vn/hopdong/27261/HOP-DONG-O-M-DUONG-BO-CAO-TOC
# HỢP ĐỒNG O&M ĐƯỜNG BỘ CAO TỐC (12394 từ)
# → https://thuvienphapluat.vn/hopdong/27255/HOP-DONG-HUONG-DAN-THUC-HANH-KHAM-BENH-CHUA-BENH
# HỢP ĐỒNG HƯỚNG DẪN THỰC HÀNH KHÁM BỆNH, CHỮA BỆNH (2433 từ)
# → https://thuvienphapluat.vn/hopdong/26393/HOP-DONG-THUE-NHA-O-CONG-VU-DO-BO-QUOC-PHONG-BAN-HANH
# HỢP ĐỒNG THUÊ NHÀ Ở CÔNG VỤ DO BỘ QUỐC PHÒNG BAN HÀNH (3790 từ)
# → https://thuvienphapluat.vn/hopdong/26391/HOP-DONG-UY-QUYEN-QUAN-LY-VAN-HANH-BAO-TRI-VA-QUAN-LY-CHO-THUE-NHA-O-CONG-VU-DO-BO-QUOC-PHONG-BAN-HANH
# HỢP ĐỒNG ỦY QUYỀN QUẢN LÝ VẬN HÀNH, BẢO TRÌ VÀ QUẢN LÝ CHO THUÊ NHÀ Ở CÔNG VỤ DO BỘ QUỐC PHÒNG BAN HÀNH (3594 từ)
# → https://thuvienphapluat.vn/hopdong/26382/HOP-DONG-TIN-DUNG-CHO-VAY-KY-QUY-DOI-VOI-NGUOI-LAO-DONG-DI-LAM-VIEC-TAI-HAN-QUOC-THEO-CHUONG-TRINH-CAP-PHEP-VIEC-LAM-CHO-LAO-DONG-NUOC-NGOAI-CUA-HAN-QUOC
# HỢP ĐỒNG TÍN DỤNG (CHO VAY KÝ QUỸ ĐỐI VỚI NGƯỜI LAO ĐỘNG ĐI LÀM VIỆC TẠI HÀN QUỐC THEO CHƯƠNG TRÌNH CẤP PHÉP VIỆC LÀM CHO LAO ĐỘNG NƯỚC NGOÀI CỦA HÀN QUỐC) (2817 từ)
# → https://thuvienphapluat.vn/hopdong/25253/MAU-HOP-DONG-THUE-XE-DANH-CHO-TO-CHUC
# MẪU HỢP ĐỒNG THUÊ XE (DÀNH CHO TỔ CHỨC) (2378 từ)
# → https://thuvienphapluat.vn/hopdong/24643/HOP-DONG-CU-THE-MUA-BAN-CO-KY-HAN-GIAY-TO-CO-GIA
# HỢP ĐỒNG CỤ THỂ MUA_BÁN CÓ KỲ HẠN GIẤY TỜ CÓ GIÁ (2215 từ)
# → https://thuvienphapluat.vn/hopdong/24640/HOP-DONG-KHUNG-MUA-BAN-GIAY-TO-CO-GIA
# HỢP ĐỒNG KHUNG MUA_BÁN GIẤY TỜ CÓ GIÁ (3086 từ)
# → https://thuvienphapluat.vn/hopdong/24637/HOP-DONG-TAI-CAP-VON-DUOI-HINH-THUC-CHO-VAY-LAI-THEO-HO-SO-TIN-DUNG
# HỢP ĐỒNG TÁI CẤP VỐN DƯỚI HÌNH THỨC CHO VAY LẠI THEO HỒ SƠ TÍN DỤNG (2242 từ)
# → https://thuvienphapluat.vn/hopdong/24633/HOP-DONG-DICH-VU-VE-VIEC-TO-CHUC-THI-HANH-AN
# HỢP ĐỒNG DỊCH VỤ VỀ VIỆC TỔ CHỨC THI HÀNH ÁN (2563 từ)
# → https://thuvienphapluat.vn/hopdong/24632/HOP-DONG-DICH-VU-VE-VIEC-XAC-MINH-DIEU-KIEN-THI-HANH-AN
# HỢP ĐỒNG DỊCH VỤ VỀ VIỆC XÁC MINH ĐIỀU KIỆN THI HÀNH ÁN (2599 từ)
# → https://thuvienphapluat.vn/hopdong/24628/HOP-DONG-DICH-VU-VE-VIEC-LAP-VI-BANG
# HỢP ĐỒNG DỊCH VỤ VỀ VIỆC LẬP VI BẰNG (2452 từ)
# → https://thuvienphapluat.vn/hopdong/24627/HOP-DONG-DICH-VU-VE-VIEC-TONG-DAT-GIAY-TO-HO-SO-TAI-LIEU
# HỢP ĐỒNG DỊCH VỤ VỀ VIỆC TỐNG ĐẠT GIẤY TỜ, HỒ SƠ, TÀI LIỆU (2906 từ)
# → https://thuvienphapluat.vn/hopdong/24626/HOP-DONG-CHUYEN-NHUONG-VAN-PHONG-THUA-PHAT-LAI
# HỢP ĐỒNG CHUYỂN NHƯỢNG VĂN PHÒNG THỪA PHÁT LẠI (1993 từ)
# → https://thuvienphapluat.vn/hopdong/21711/HOP-DONG-CUNG-CAP-DICH-VU-BU-TRU-VA-THANH-TOAN-GIAO-DICH-CHUNG-KHOAN-PHAI-SINH
# Điều 2.Trách nhiệm và quyền hạn của Bên A (4483 từ)
# → https://thuvienphapluat.vn/hopdong/20980/HOP-DONG-DOI-TAC-CONG-TU-THANH-LAP-CHUONG-TRINH-PPP
# HỢP ĐỒNG ĐỐI TÁC CÔNG - TƯ THÀNH LẬP CHƯƠNG TRÌNH PPP (3385 từ)
# → https://thuvienphapluat.vn/hopdong/20536/HOP-DONG-CUNG-CAP-KHAI-THAC-SU-DUNG-THONG-TIN-DU-LIEU-TAI-NGUYEN-VA-MOI-TRUONG
# HỢP ĐỒNG CUNG CẤP, KHAI THÁC, SỬ DỤNG THÔNG TIN, DỮ LIỆU TÀI NGUYÊN VÀ MÔI TRƯỜNG (2014 từ)
# → https://thuvienphapluat.vn/hopdong/150/BIEN-BAN-THANH-LY-HOP-DONG
# → https://thuvienphapluat.vn/hopdong/156/HOP-DONG-HOP-TAC-KINH-DOANH-mau-1
# → https://thuvienphapluat.vn/hopdong/109/HOP-DONG-MUA-BAN-HANG-HOA
# → https://thuvienphapluat.vn/hopdong/230/HOP-DONG-MUA-BAN-NHA-O-mau-2
# → https://thuvienphapluat.vn/hopdong/130/HOP-DONG-NGUYEN-TAC-BAN-HANG
#
# === HOÀN TẤT ===
# Tổng: 104
# Lưu: contracts_html_window
# Manifest: contracts_html_window_manifest.csv

# %% [markdown]
# #**TỔNG HỢP CÁC FILE HỢP ĐỒNG**

# %%
import os

# Thư mục chứa các file TXT
input_dir = "/content/TongHop"
output_file = "/content/noidungtong.txt"

# Mở file kết quả để ghi toàn bộ nội dung
with open(output_file, "w", encoding="utf-8") as outfile:
    # Lặp qua toàn bộ file trong thư mục
    for filename in sorted(os.listdir(input_dir)):
        if filename.endswith(".txt"):
            file_path = os.path.join(input_dir, filename)
            with open(file_path, "r", encoding="utf-8") as infile:
                outfile.write(f"\n\n===== {filename} =====\n\n")  # tiêu đề phân cách
                outfile.write(infile.read())
                outfile.write("\n\n")

print("Đã gộp xong tất cả các file .txt vào:", output_file)
# Out:
# Đã gộp xong tất cả các file .txt vào: /content/noidungtong.txt

# %%
from google.colab import files
files.download("/content/noidungtong.txt")
