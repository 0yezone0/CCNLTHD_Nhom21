# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import math

# %%
class PositionalEncoding(nn.Module):
    """
    Lớp Positional Encoding thêm thông tin vị trí vào embedding của từ
    Args:
        d_model (int): Kích thước của vector embedding
        max_len (int): Độ dài tối đa của chuỗi đầu vào (mặc định: 5000)
    """
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        # Tạo ma trận positional encoding có kích thước (max_len, d_model)
        pe = torch.zeros(max_len, d_model)
        # Tạo vector position từ 0 đến max_len-1
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        # Tính các giá trị chia để tạo các tần số khác nhau
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        # Áp dụng hàm sin cho các vị trí chẵn
        pe[:, 0::2] = torch.sin(position * div_term)
        # Áp dụng hàm cos cho các vị trí lẻ  
        pe[:, 1::2] = torch.cos(position * div_term)
        # Thêm chiều batch
        pe = pe.unsqueeze(0)
        # Đăng ký buffer để lưu trữ giá trị PE
        self.register_buffer('pe', pe)

    def forward(self, x):
        """
        Args:
            x: Tensor đầu vào shape (batch_size, seq_len, d_model)
        Returns:
            Tensor đầu ra đã thêm positional encoding
        """
        return x + self.pe[:, :x.size(1)]

class MultiHeadAttention(nn.Module):
    """
    Lớp Multi-Head Attention cho phép mô hình học nhiều biểu diễn (representation)
    khác nhau của mối quan hệ giữa các từ trong câu cùng lúc.

    Thay vì chỉ có một "cái nhìn" (một head attention),
    mô hình chia không gian embedding thành nhiều phần nhỏ hơn (num_heads),
    mỗi head sẽ học một dạng quan hệ riêng biệt (ví dụ: ngữ pháp, ngữ nghĩa...).

    Args:
        d_model (int): Kích thước của vector embedding đầu vào (thường là 512)
        num_heads (int): Số lượng "đầu" attention (ví dụ: 8)
        dropout (float): Tỷ lệ dropout (mặc định: 0.1)
    """
    def __init__(self, d_model, num_heads, dropout=0.1):
        super().__init__()

        # Đảm bảo số chiều chia hết cho số head
        assert d_model % num_heads == 0, "d_model phải chia hết cho num_heads"
        
        self.d_model = d_model
        self.num_heads = num_heads
        # Kích thước của mỗi head (ví dụ: 512 / 8 = 64)
        self.d_k = d_model // num_heads
        
        # Các lớp Linear để chiếu (project) đầu vào sang Q, K, V
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        # Lớp Linear cuối cùng để ghép các head thành một vector d_model
        self.W_o = nn.Linear(d_model, d_model)
        
        self.dropout = nn.Dropout(dropout)


    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        """
        Thực hiện tính toán **Scaled Dot-Product Attention** cho từng head.

        Args:
            Q (Tensor): Query tensor có kích thước (batch, num_heads, seq_len_q, d_k)
            K (Tensor): Key tensor có kích thước (batch, num_heads, seq_len_k, d_k)
            V (Tensor): Value tensor có kích thước (batch, num_heads, seq_len_k, d_k)
            mask (Tensor, optional): Mask dùng để che các vị trí không hợp lệ
                                     (ví dụ: padding hoặc future tokens trong decoder)

        Returns:
            output (Tensor): Kết quả sau attention (batch, num_heads, seq_len_q, d_k)
            attn_weights (Tensor): Ma trận trọng số attention (batch, num_heads, seq_len_q, seq_len_k)
        """

        # Tính điểm tương đồng (attention scores) giữa Q và K 
        #   Mỗi phần tử biểu diễn độ liên quan giữa token query và token key
        #   -> Shape: (batch, num_heads, seq_len_q, seq_len_k)
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        # Áp dụng mask nếu có 
        #   Dùng cho:
        #   - Padding mask: loại bỏ attention với các vị trí là <PAD>
        #   - Look-ahead mask: ngăn nhìn token tương lai (trong decoder)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)  # -inf khiến softmax ≈ 0

        # Chuẩn hóa bằng softmax để ra phân phối attention 
        attn_weights = F.softmax(scores, dim=-1)
        # Dropout để tránh overfitting
        attn_weights = self.dropout(attn_weights)

        # Nhân trọng số attention với V để lấy đầu ra 
        #   -> Mỗi token query bây giờ là tổng trọng số (weighted sum) của các value tương ứng
        output = torch.matmul(attn_weights, V)

        # Trả về:
        # - output: giá trị tổng hợp theo attention
        # - attn_weights: ma trận thể hiện "token nào chú ý tới token nào"
        return output, attn_weights


    def split_heads(self, x):
        """
        Chia tensor đầu vào thành nhiều head.

        Trước: (batch_size, seq_len, d_model)
        Sau:   (batch_size, num_heads, seq_len, d_k)
        """
        batch_size, seq_len, d_model = x.size()

        # Chia d_model thành num_heads phần
        x = x.view(batch_size, seq_len, self.num_heads, self.d_k)

        # Đưa trục num_heads ra trước (để dễ tính attention giữa các head)
        x = x.transpose(1, 2)
        return x


    def combine_heads(self, x):
        """
        Kết hợp các head sau khi attention xong thành một tensor duy nhất.

        Trước: (batch_size, num_heads, seq_len, d_k)
        Sau:   (batch_size, seq_len, d_model)
        """
        batch_size, num_heads, seq_len, d_k = x.size()

        # Đưa lại trục seq_len về trước
        x = x.transpose(1, 2).contiguous()

        # Ghép các head lại (num_heads * d_k = d_model)
        x = x.view(batch_size, seq_len, self.d_model)
        return x


    def forward(self, Q, K, V, mask=None):
        """
        Forward pass của Multi-Head Attention:
            1. Chiếu Q, K, V sang không gian mới bằng Linear
            2. Chia thành nhiều head
            3. Tính scaled dot-product attention cho từng head
            4. Gộp các head lại
            5. Chiếu qua Linear cuối cùng (W_o)

        Args:
            Q, K, V (Tensor): Các tensor đầu vào (batch, seq_len, d_model)
            mask (Tensor, optional): Mask attention

        Returns:
            output (Tensor): Đầu ra đã attention (batch, seq_len, d_model)
            attn_weights (Tensor): Trọng số attention (batch, num_heads, seq_len_q, seq_len_k)
        """
        # Chiếu sang không gian mới 
        Q = self.W_q(Q)  # (batch, seq_len, d_model)
        K = self.W_k(K)
        V = self.W_v(V)

        # Chia thành nhiều head 
        Q = self.split_heads(Q)
        K = self.split_heads(K)
        V = self.split_heads(V)

        # Tính attention cho từng head 
        attn_output, attn_weights = self.scaled_dot_product_attention(Q, K, V, mask)

        # Gộp các head lại 
        attn_output = self.combine_heads(attn_output)

        # Chiếu qua Linear cuối cùng 
        output = self.W_o(attn_output)

        return output, attn_weights

class FeedForward(nn.Module):
    """
    Lớp FeedForward mạng nơ-ron cho từng vị trí trong chuỗi (Position-wise Feed Forward Network)

    Mỗi token sau khi qua cơ chế attention sẽ đi qua mạng feedforward
    gồm 2 tầng Linear để tăng tính phi tuyến tính và học đặc trưng sâu hơn.

    Args:
        d_model (int): Kích thước vector đầu vào (embedding dimension)
        d_ff (int): Kích thước tầng ẩn (thường lớn hơn d_model, ví dụ: 2048)
        dropout (float): Tỷ lệ dropout để tránh overfitting
    """
    def __init__(self, d_model, d_ff, dropout=0.1):
        super().__init__()
        # Linear 1: mở rộng số chiều từ d_model -> d_ff
        self.linear1 = nn.Linear(d_model, d_ff)
        # Dropout để tránh overfitting
        self.dropout = nn.Dropout(dropout)
        # Linear 2: thu hẹp số chiều từ d_ff -> d_model
        self.linear2 = nn.Linear(d_ff, d_model)
    
    def forward(self, x):
        """
        Forward pass:
            1. Linear -> ReLU -> Dropout -> Linear
        """
        # ReLU tạo phi tuyến tính giúp mô hình học được đặc trưng phức tạp
        x = self.linear1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        return x


class EncoderLayer(nn.Module):
    """
    Lớp Encoder Layer trong Transformer.

    Mỗi encoder layer gồm 2 phần chính:
        1. Multi-Head Self-Attention (tự chú ý trên chính chuỗi đầu vào)
        2. FeedForward network (tăng tính phi tuyến)

    Cả hai phần đều được bao quanh bởi:
        - Residual Connection (kết nối tắt)
        - Layer Normalization (chuẩn hóa từng vị trí trong vector)

    Args:
        d_model (int): Kích thước vector embedding
        num_heads (int): Số lượng đầu attention
        d_ff (int): Kích thước hidden layer trong FeedForward
        dropout (float): Tỷ lệ dropout
    """
    def __init__(self, d_model, num_heads, d_ff, dropout=0.1):
        super().__init__()
        # Cơ chế tự chú ý (Self-Attention)
        self.self_attn = MultiHeadAttention(d_model, num_heads, dropout)
        # Mạng feedforward
        self.feed_forward = FeedForward(d_model, d_ff, dropout)
        # Chuẩn hóa sau mỗi khối (LayerNorm giúp ổn định quá trình huấn luyện)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        # Dropout để tránh overfitting
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, mask=None):
        """
        Forward pass:
        - Input: x (batch_size, seq_len, d_model)
        - Output: x đã được attention + feedforward
        """
        # Self-Attention
        attn_output, _ = self.self_attn(x, x, x, mask)  # Q=K=V=x
        # Residual connection + LayerNorm
        x = self.norm1(x + self.dropout(attn_output))

        # Feed Forward
        ff_output = self.feed_forward(x)
        # Residual connection + LayerNorm
        x = self.norm2(x + self.dropout(ff_output))

        # Kết quả: x sau khi đã được attention và feedforward xử lý
        return x


class DecoderLayer(nn.Module):
    """
    Lớp Decoder Layer trong Transformer.

    Mỗi decoder layer gồm 3 phần chính:
        1. Masked Multi-Head Self-Attention (chỉ nhìn thấy các token trước)
        2. Cross-Attention (chú ý đến đầu ra của Encoder)
        3. FeedForward network

    Giống như encoder, mỗi phần đều có Residual connection + LayerNorm.

    Args:
        d_model (int): Kích thước vector embedding
        num_heads (int): Số lượng đầu attention
        d_ff (int): Kích thước hidden layer trong FeedForward
        dropout (float): Tỷ lệ dropout
    """
    def __init__(self, d_model, num_heads, d_ff, dropout=0.1):
        super().__init__()
        # Self-Attention (mask để ngăn nhìn token tương lai)
        self.self_attn = MultiHeadAttention(d_model, num_heads, dropout)
        # Cross-Attention (giữa decoder và encoder output)
        self.cross_attn = MultiHeadAttention(d_model, num_heads, dropout)
        # FeedForward
        self.feed_forward = FeedForward(d_model, d_ff, dropout)
        # Chuẩn hóa sau mỗi phần
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        # Dropout
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x, enc_output, src_mask=None, tgt_mask=None):
        """
        Forward pass trong decoder layer:
            x: đầu vào của decoder (batch_size, tgt_seq_len, d_model)
            enc_output: đầu ra của encoder (batch_size, src_seq_len, d_model)
        """
        # Masked Self-Attention
        # Decoder chỉ nhìn thấy các token trước đó (qua tgt_mask)
        attn_output, _ = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))

        # Cross-Attention 
        # Decoder chú ý đến đầu ra của Encoder (nguồn ngữ cảnh)
        attn_output, _ = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))

        # Feed Forward
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))

        # Kết quả: đầu ra sau khi qua 3 khối của decoder
        return x

class Transformer(nn.Module):
    """
    Mô hình Transformer Encoder–Decoder hoàn chỉnh
    Bao gồm:
      - Embedding + Positional Encoding
      - Nhiều lớp Encoder
      - Nhiều lớp Decoder
      - Linear cuối cùng sinh ra phân phối xác suất trên từ vựng đích
    """

    def __init__(self, src_vocab_size, tgt_vocab_size, 
                 d_model=512, num_heads=8, 
                 num_encoder_layers=6, num_decoder_layers=6, 
                 d_ff=2048, max_seq_len=5000, dropout=0.1):
        super().__init__()

        # Embedding
        # Chuyển mỗi token trong câu nguồn (src) / câu đích (tgt)
        # thành vector liên tục có kích thước d_model
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)

        # Positional Encoding
        # Thêm thông tin vị trí (position) cho từng token
        # để mô hình hiểu thứ tự từ trong chuỗi
        self.positional_encoding = PositionalEncoding(d_model, max_seq_len)

        # Encoder
        # Gồm nhiều lớp EncoderLayer (mỗi lớp = self-attention + feed-forward)
        self.encoder_layers = nn.ModuleList([
            EncoderLayer(d_model, num_heads, d_ff, dropout)
            for _ in range(num_encoder_layers)
        ])

        # Decoder
        # Gồm nhiều lớp DecoderLayer (mỗi lớp = self-attention + cross-attention + feed-forward)
        self.decoder_layers = nn.ModuleList([
            DecoderLayer(d_model, num_heads, d_ff, dropout)
            for _ in range(num_decoder_layers)
        ])

        # Output layer
        # Biến đầu ra của decoder (d_model) thành phân phối xác suất trên vocab đích
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)

        # Dropout toàn cục cho embedding + positional encoding
        self.dropout = nn.Dropout(dropout)

        # Lưu d_model để scale embedding (theo paper gốc)
        self.d_model = d_model

    # MASK: che padding token + che tương lai (causal mask)
    def generate_mask(self, src, tgt):
        """
        Sinh ra 2 loại mask:
          - src_mask: che các token padding trong chuỗi nguồn
          - tgt_mask: che padding và che nhìn về phía trước (no-peak mask)
        """
        # src_mask có shape (batch, 1, 1, src_len)
        # => 1 nghĩa là vị trí hợp lệ, 0 nghĩa là padding
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)

        # tgt_mask ban đầu: che padding (batch, 1, tgt_len, 1)
        tgt_mask = (tgt != 0).unsqueeze(1).unsqueeze(3)

        # nopeak_mask: tam giác dưới (1 cho phép, 0 che)
        # đảm bảo mỗi vị trí trong decoder chỉ nhìn thấy token trước nó
        seq_len = tgt.size(1)
        nopeak_mask = (1 - torch.triu(torch.ones(1, seq_len, seq_len), diagonal=1)).bool()
        nopeak_mask = nopeak_mask.to(tgt.device)

        # Kết hợp mask padding và mask tương lai
        # Kết quả: tgt_mask có shape (batch, 1, tgt_len, tgt_len)
        tgt_mask = tgt_mask & nopeak_mask

        return src_mask, tgt_mask

    
    # truyền dữ liệu qua toàn bộ mô hình
    def forward(self, src, tgt):
        """
        src: tensor (batch_size, src_seq_len)
        tgt: tensor (batch_size, tgt_seq_len)

        Trả về:
          - output: (batch_size, tgt_seq_len, tgt_vocab_size)
        """

        # Sinh mask cho encoder và decoder
        src_mask, tgt_mask = self.generate_mask(src, tgt)

        # Embedding + Positional Encoding
        # Nhân sqrt(d_model): giữ scale ổn định giữa embedding và positional encoding
        src_embedded = self.encoder_embedding(src) * math.sqrt(self.d_model)
        src_embedded = self.positional_encoding(src_embedded)
        src_embedded = self.dropout(src_embedded)

        tgt_embedded = self.decoder_embedding(tgt) * math.sqrt(self.d_model)
        tgt_embedded = self.positional_encoding(tgt_embedded)
        tgt_embedded = self.dropout(tgt_embedded)

        # Shape sau bước này:
        # src_embedded: (batch, src_seq_len, d_model)
        # tgt_embedded: (batch, tgt_seq_len, d_model)

        # Encoder
        # Duyệt qua từng lớp encoder
        # Mỗi lớp gồm: self-attention + feed-forward + residual + layer norm
        enc_output = src_embedded
        for layer in self.encoder_layers:
            enc_output = layer(enc_output, src_mask)
        # enc_output: (batch, src_seq_len, d_model)

        # Decoder 
        # Duyệt qua từng lớp decoder
        # Mỗi lớp gồm: self-attention (với tgt_mask), cross-attention (với src_mask), feed-forward
        dec_output = tgt_embedded
        for layer in self.decoder_layers:
            dec_output = layer(dec_output, enc_output, src_mask, tgt_mask)
        # dec_output: (batch, tgt_seq_len, d_model)

        # Projection sang vocab đích 
        # Biến vector d_model thành xác suất cho từng token
        output = self.fc_out(dec_output)
        # output: (batch, tgt_seq_len, tgt_vocab_size)

        return output

# %%
# Hyperparameters
src_vocab_size = 10000 # Kích thước từ vựng nguồn
tgt_vocab_size = 10000 # Kích thước từ vựng đích
d_model = 512 # Kích thước của vector embedding
num_heads = 8 # Số lượng head attention
num_encoder_layers = 6 # Số lượng lớp encoder
num_decoder_layers = 6 # Số lượng lớp decoder
d_ff = 2048 # Kích thước của hidden layer
max_seq_len = 100 # Độ dài tối đa của chuỗi đầu vào
dropout = 0.1 # Tỉ lệ dropout

# Tạo model
model = Transformer(
    src_vocab_size, tgt_vocab_size, d_model, num_heads,
    num_encoder_layers, num_decoder_layers, d_ff, max_seq_len, dropout
)

# Input ví dụ (batch_size=2, seq_len=10)
src = torch.randint(1, src_vocab_size, (2, 10))
tgt = torch.randint(1, tgt_vocab_size, (2, 10))


output = model(src, tgt)
print(f"Input shape: {src.shape}")
print(f"Output shape: {output.shape}")  # [batch_size, seq_len, tgt_vocab_size]
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Input shape: torch.Size([2, 10])
# Output shape: torch.Size([2, 10, 10000])
# Model parameters: 59,508,496
